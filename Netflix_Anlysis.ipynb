# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajinkyad2022/Data-Analysis-Project/blob/main/Netflix_Anlysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
data = pd.read_csv('/netflix.csv')
data
# Out:
#                                                  title               genre  \
# 0                                     Notes for My Son               Drama
# 1                                     To Each, Her Own     Romantic comedy
# 2                                        The Lovebirds     Romantic comedy
# 3                                       The Perfection     Horror-thriller
# 4                                    Happy Anniversary     Romantic comedy
# ..                                                 ...                 ...
# 578  Rolling Thunder Revue: A bob Dylan Story by Ma...         Documentary
# 579                           Freaks: You're One of Us  Supernatural drama
# 580                                       Squared Love     Romantic comedy
# 581                                         My Own Man         Documentary
# 582                      Biggie: I Got a Story to Tell         Documentary
#
#     language  imdb_score    premiere  runtime  year
# ...

# %%
from matplotlib import pyplot as plt
_df_14['runtime'].plot(kind='line', figsize=(8, 4), title='runtime')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
data.imdb_score.plot(kind="hist")

# %%
data.dtypes
# Out:
# title          object
# genre          object
# language       object
# imdb_score    float64
# premiere       object
# runtime         int64
# year            int64
# dtype: object

# %%
data.imdb_score.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.genre.describe()
# Out:
# count             583
# unique            114
# top       Documentary
# freq              159
# Name: genre, dtype: object

# %%
data.genre.value_counts()
# Out:
# genre
# Documentary                    159
# Drama                           77
# Comedy                          49
# Romantic comedy                 39
# Thriller                        33
#                               ...
# Political thriller               1
# Fantasy                          1
# Romantic comedy-drama            1
# Animation/Musical/Adventure      1
# Supernatural drama               1
# Name: count, Length: 114, dtype: int64

# %%
data.genre.value_counts(normalize=True)
# Out:
# genre
# Documentary                    0.272727
# Drama                          0.132075
# Comedy                         0.084048
# Romantic comedy                0.066895
# Thriller                       0.056604
#                                  ...
# Political thriller             0.001715
# Fantasy                        0.001715
# Romantic comedy-drama          0.001715
# Animation/Musical/Adventure    0.001715
# Supernatural drama             0.001715
# Name: proportion, Length: 114, dtype: float64

# %%
data.genre.unique()
# Out:
# array(['Drama', 'Romantic comedy', 'Horror-thriller', 'Documentary',
#        'Comedy', 'Comedy / Musical', 'Animation / Short', 'Action',
#        'Crime thriller', 'Horror', 'Romance', 'Thriller', 'Action/Comedy',
#        'War', 'Concert Film', 'Variety show', 'Comedy-drama',
#        'Musical/Western/Fantasy', 'Heist', 'Western',
#        'Action/Science fiction', 'Dark comedy', 'Family film',
#        'Action comedy', 'Romantic teen drama', 'One-man show',
#        'Animation', 'Drama / Short', 'Action-thriller', 'Romantic drama',
#        'Biopic', 'Crime drama', 'Heist film/Thriller', 'Science fiction',
#        'Coming-of-age comedy-drama', 'Comedy/Horror',
#        'Science fiction/Thriller', 'Psychological thriller drama',
#        'Spy thriller', 'Sports film', 'Comedy horror',
#        'Romantic comedy/Holiday', 'Romantic teenage drama',
#        'Superhero/Action', 'Adventure', 'Science fiction thriller',
#        'Musical / Short', 'Science fiction/Drama', 'Family',
# ...

# %%
data.year.value_counts().plot(kind="bar")
data
# Out:
#                                                  title               genre  \
# 0                                     Notes for My Son               Drama
# 1                                     To Each, Her Own     Romantic comedy
# 2                                        The Lovebirds     Romantic comedy
# 3                                       The Perfection     Horror-thriller
# 4                                    Happy Anniversary     Romantic comedy
# ..                                                 ...                 ...
# 578  Rolling Thunder Revue: A bob Dylan Story by Ma...         Documentary
# 579                           Freaks: You're One of Us  Supernatural drama
# 580                                       Squared Love     Romantic comedy
# 581                                         My Own Man         Documentary
# 582                      Biggie: I Got a Story to Tell         Documentary
#
#     language  imdb_score    premiere  runtime  year
# ...

# %%
data.year.value_counts().plot(kind="sct")
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-1f52a816fc50> in <cell line: 1>()
# ----> 1 data.year.value_counts().plot(kind="sct")
#       2 data
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     958
#     959         if kind not in self._all_kinds:
# --> 960             raise ValueError(
#     961                 f"{kind} is not a valid plot kind "
#     962                 f"Valid plot kinds: {self._all_kinds}"
#
# ValueError: sct is not a valid plot kind Valid plot kinds: ('line', 'bar', 'barh', 'kde', 'density', 'area', 'hist', 'box', 'pie', 'scatter', 'hexbin')

# %%
fig = px.scatter(data,y="year", x="title")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.pie(data,names="genre")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-9f11e14206ab> in <cell line: 1>()
# ----> 1 fig=px.bar(data,names="genre")
#       2 fig.show()
#
# TypeError: bar() got an unexpected keyword argument 'names'

# %%
data.language.value_counts().plot(kind="donte")
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-9a94a6997851> in <cell line: 1>()
# ----> 1 data.language.value_counts().plot(kind="donte")
#       2 data
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     958
#     959         if kind not in self._all_kinds:
# --> 960             raise ValueError(
#     961                 f"{kind} is not a valid plot kind "
#     962                 f"Valid plot kinds: {self._all_kinds}"
#
# ValueError: donte is not a valid plot kind Valid plot kinds: ('line', 'bar', 'barh', 'kde', 'density', 'area', 'hist', 'box', 'pie', 'scatter', 'hexbin')

# %%
fig = px.scatter(data,y="language", x="title")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
